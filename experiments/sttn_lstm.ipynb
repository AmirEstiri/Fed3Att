# %%
import time
import numpy as np
import pandas as pd
import tensorflow as tf

import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)  # suppress warnings

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
B = 8
H = 10 # Grid height
W = 10 # Grid width
N = H*W # Nodes in grpah
M = 15 # previous time steps
T = 5 # future time steps
TIME_STEP = 60

# %%
def normalize(vec):
    return (vec-min(vec))/(max(vec)-min(vec))

df = pd.read_csv('gdrive/MyDrive/trace/trace_avg.csv')
MAX_COST = 200
df = df[df['Cost'] < MAX_COST]
df['Cost'] = df['Cost'] / MAX_COST
df['Long'] = normalize(df['Long'])
df['Lat'] = normalize(df['Lat'])

df['TimeStep'] = round(df['TimeSec'] / TIME_STEP)
df['LongStep'] = round(df['Long'] * (H-1))
df['LatStep'] = round(df['Lat'] * (W-1))
df['GraphNode'] = (df['LongStep']-1) * W + df['LatStep']
df = df.groupby(['GraphNode', 'TimeStep'])['Cost'].mean().reset_index()

############################################################

times = np.unique(df['TimeStep'])
dataset = []

for t in times:
    grid = np.ones((H*W, 1)) * -1
    df_t = df[df['TimeStep'] == t]
    for index, row in df_t.iterrows():
        lat_step = row['GraphNode'] % W
        long_step = (row['GraphNode'] - lat_step) / W + 1
        index = int(W*(long_step-1)+lat_step)
        grid[index] = row['Cost']
    dataset.append(grid)
dataset = np.array(dataset)
del df

############################################################

indf = []
outdf = []

for i in range(len(dataset)-M-T-1):
    indf.append(dataset[i:i+M])
    outdf.append(dataset[i+M:i+M+T])

del dataset

L = len(indf)
l = L-L%B
indf = np.swapaxes(np.array(indf), 1, 2)[:l]
outdf = np.swapaxes(np.array(outdf), 1, 2)[:l]

indf = np.reshape(indf, (-1, B, indf.shape[1], indf.shape[2]))
outdf = np.reshape(outdf, (-1, B, outdf.shape[1], outdf.shape[2]))

l = int(0.9*len(indf))
indf_train = indf[:l]
outdf_train = outdf[:l]
indf_test = indf[l:]
outdf_test = outdf[l:]

# %%
def loss_function(real, pred, loss_func):
    mask = tf.math.logical_not(tf.math.equal(real, -1.0))
    if loss_func == 'MSE':
        loss = tf.square(tf.cast(real, dtype=tf.float32) - tf.cast(pred, dtype=tf.float32))
    elif loss_func == 'MAE':
        loss = tf.abs(tf.cast(real, dtype=tf.float32) - tf.cast(pred, dtype=tf.float32))
    mask = tf.cast(mask, dtype=loss.dtype)
    loss *= mask
    return tf.reduce_sum(loss)/tf.reduce_sum(mask)


class LSTMModel(tf.keras.Model):

  def __init__(self, T):
    super(LSTMModel, self).__init__()
    self.lstm1 = tf.keras.layers.LSTM(300, return_sequences=True)
    self.lstm2 = tf.keras.layers.LSTM(150, return_sequences=True)
    self.dense = tf.keras.layers.LSTM(T, return_sequences=True, activation='sigmoid')


  def call(self, x):
    x = self.lstm1(x)
    x = self.lstm2(x)
    x = self.dense(x)
    return x

# %%
lstm = LSTMModel(T)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
train_loss = tf.keras.metrics.Mean(name='train_loss')

@tf.function
def train_step(inp, tar):

    with tf.GradientTape() as tape:
        pred = lstm(inp)
        loss = loss_function(tar, pred, 'MSE')

    gradients = tape.gradient(loss, lstm.trainable_variables)
    optimizer.apply_gradients(zip(gradients, lstm.trainable_variables))
    train_loss(loss)

# %%
EPOCHS = 10
beginning = time.time()
for epoch in range(EPOCHS):
    for b in range(indf_train.shape[0]):
        inp = indf_train[b]
        tar = outdf_train[b]

        train_step(inp, tar)

        if b % 10 == 0:
            print(f'Epoch {epoch + 1} Batch {b} Loss {train_loss.result():.4f}')
        
    print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f}')
print(f'Total time: {time.time() - beginning:.2f} secs\n')
# Out:
# Epoch 1 Batch 0 Loss 0.0354
# Epoch 1 Batch 10 Loss 0.0098
# Epoch 1 Batch 20 Loss 0.0063
# Epoch 1 Batch 30 Loss 0.0074
# Epoch 1 Batch 40 Loss 0.0064
# Epoch 1 Batch 50 Loss 0.0087
# Epoch 1 Batch 60 Loss 0.0077
# Epoch 1 Batch 70 Loss 0.0095
# Epoch 1 Batch 80 Loss 0.0103
# Epoch 1 Batch 90 Loss 0.0099
# Epoch 1 Batch 100 Loss 0.0106
# Epoch 1 Batch 110 Loss 0.0102
# Epoch 1 Batch 120 Loss 0.0097
# Epoch 1 Batch 130 Loss 0.0093
# Epoch 1 Loss 0.0093
# Epoch 2 Batch 0 Loss 0.0092
# Epoch 2 Batch 10 Loss 0.0090
# Epoch 2 Batch 20 Loss 0.0085
# Epoch 2 Batch 30 Loss 0.0086
# Epoch 2 Batch 40 Loss 0.0083
# Epoch 2 Batch 50 Loss 0.0087
# Epoch 2 Batch 60 Loss 0.0084
# Epoch 2 Batch 70 Loss 0.0090
# Epoch 2 Batch 80 Loss 0.0093
# Epoch 2 Batch 90 Loss 0.0092
# Epoch 2 Batch 100 Loss 0.0095
# Epoch 2 Batch 110 Loss 0.0093
# Epoch 2 Batch 120 Loss 0.0091
# Epoch 2 Batch 130 Loss 0.0090
# Epoch 2 Loss 0.0089
# Epoch 3 Batch 0 Loss 0.0089
# Epoch 3 Batch 10 Loss 0.0088
# Epoch 3 Batch 20 Loss 0.0086
# Epoch 3 Batch 30 Loss 0.0086
# Epoch 3 Batch 40 Loss 0.0084
# Epoch 3 Batch 50 Loss 0.0089
# Epoch 3 Batch 60 Loss 0.0087
# Epoch 3 Batch 70 Loss 0.0090
# Epoch 3 Batch 80 Loss 0.0093
# Epoch 3 Batch 90 Loss 0.0092
# Epoch 3 Batch 100 Loss 0.0094
# Epoch 3 Batch 110 Loss 0.0093
# Epoch 3 Batch 120 Loss 0.0092
# Epoch 3 Batch 130 Loss 0.0091
# Epoch 3 Loss 0.0091
# Epoch 4 Batch 0 Loss 0.0091
# Epoch 4 Batch 10 Loss 0.0090
# Epoch 4 Batch 20 Loss 0.0088
# Epoch 4 Batch 30 Loss 0.0089
# Epoch 4 Batch 40 Loss 0.0087
# Epoch 4 Batch 50 Loss 0.0089
# Epoch 4 Batch 60 Loss 0.0088
# Epoch 4 Batch 70 Loss 0.0090
# Epoch 4 Batch 80 Loss 0.0091
# Epoch 4 Batch 90 Loss 0.0091
# Epoch 4 Batch 100 Loss 0.0092
# Epoch 4 Batch 110 Loss 0.0092
# Epoch 4 Batch 120 Loss 0.0091
# Epoch 4 Batch 130 Loss 0.0090
# Epoch 4 Loss 0.0090
# Epoch 5 Batch 0 Loss 0.0090
# Epoch 5 Batch 10 Loss 0.0089
# Epoch 5 Batch 20 Loss 0.0088
# Epoch 5 Batch 30 Loss 0.0088
# Epoch 5 Batch 40 Loss 0.0087
# Epoch 5 Batch 50 Loss 0.0088
# Epoch 5 Batch 60 Loss 0.0087
# Epoch 5 Batch 70 Loss 0.0089
# Epoch 5 Batch 80 Loss 0.0090
# Epoch 5 Batch 90 Loss 0.0090
# Epoch 5 Batch 100 Loss 0.0091
# Epoch 5 Batch 110 Loss 0.0090
# Epoch 5 Batch 120 Loss 0.0090
# Epoch 5 Batch 130 Loss 0.0089
# Epoch 5 Loss 0.0089
# Epoch 6 Batch 0 Loss 0.0089
# Epoch 6 Batch 10 Loss 0.0088
# Epoch 6 Batch 20 Loss 0.0087
# Epoch 6 Batch 30 Loss 0.0087
# Epoch 6 Batch 40 Loss 0.0086
# Epoch 6 Batch 50 Loss 0.0088
# Epoch 6 Batch 60 Loss 0.0087
# Epoch 6 Batch 70 Loss 0.0088
# Epoch 6 Batch 80 Loss 0.0089
# Epoch 6 Batch 90 Loss 0.0089
# Epoch 6 Batch 100 Loss 0.0090
# Epoch 6 Batch 110 Loss 0.0089
# Epoch 6 Batch 120 Loss 0.0089
# Epoch 6 Batch 130 Loss 0.0088
# Epoch 6 Loss 0.0088
# Epoch 7 Batch 0 Loss 0.0088
# Epoch 7 Batch 10 Loss 0.0088
# Epoch 7 Batch 20 Loss 0.0087
# Epoch 7 Batch 30 Loss 0.0087
# Epoch 7 Batch 40 Loss 0.0086
# Epoch 7 Batch 50 Loss 0.0087
# Epoch 7 Batch 60 Loss 0.0087
# Epoch 7 Batch 70 Loss 0.0088
# Epoch 7 Batch 80 Loss 0.0088
# Epoch 7 Batch 90 Loss 0.0088
# Epoch 7 Batch 100 Loss 0.0089
# Epoch 7 Batch 110 Loss 0.0088
# Epoch 7 Batch 120 Loss 0.0088
# Epoch 7 Batch 130 Loss 0.0087
# Epoch 7 Loss 0.0087
# Epoch 8 Batch 0 Loss 0.0087
# Epoch 8 Batch 10 Loss 0.0087
# Epoch 8 Batch 20 Loss 0.0086
# Epoch 8 Batch 30 Loss 0.0086
# Epoch 8 Batch 40 Loss 0.0086
# Epoch 8 Batch 50 Loss 0.0086
# Epoch 8 Batch 60 Loss 0.0086
# Epoch 8 Batch 70 Loss 0.0087
# Epoch 8 Batch 80 Loss 0.0087
# Epoch 8 Batch 90 Loss 0.0087
# Epoch 8 Batch 100 Loss 0.0088
# Epoch 8 Batch 110 Loss 0.0087
# Epoch 8 Batch 120 Loss 0.0087
# Epoch 8 Batch 130 Loss 0.0086
# Epoch 8 Loss 0.0086
# Epoch 9 Batch 0 Loss 0.0086
# Epoch 9 Batch 10 Loss 0.0086
# Epoch 9 Batch 20 Loss 0.0086
# Epoch 9 Batch 30 Loss 0.0085
# Epoch 9 Batch 40 Loss 0.0085
# Epoch 9 Batch 50 Loss 0.0086
# Epoch 9 Batch 60 Loss 0.0085
# Epoch 9 Batch 70 Loss 0.0086
# Epoch 9 Batch 80 Loss 0.0086
# Epoch 9 Batch 90 Loss 0.0086
# Epoch 9 Batch 100 Loss 0.0087
# Epoch 9 Batch 110 Loss 0.0086
# Epoch 9 Batch 120 Loss 0.0086
# Epoch 9 Batch 130 Loss 0.0086
# Epoch 9 Loss 0.0086
# Epoch 10 Batch 0 Loss 0.0086
# Epoch 10 Batch 10 Loss 0.0085
# Epoch 10 Batch 20 Loss 0.0085
# Epoch 10 Batch 30 Loss 0.0085
# Epoch 10 Batch 40 Loss 0.0084
# Epoch 10 Batch 50 Loss 0.0085
# Epoch 10 Batch 60 Loss 0.0084
# Epoch 10 Batch 70 Loss 0.0085
# Epoch 10 Batch 80 Loss 0.0086
# Epoch 10 Batch 90 Loss 0.0085
# Epoch 10 Batch 100 Loss 0.0086
# Epoch 10 Batch 110 Loss 0.0086
# Epoch 10 Batch 120 Loss 0.0085
# Epoch 10 Batch 130 Loss 0.0085
# Epoch 10 Loss 0.0085
# Total time: 497.81 secs

# %%
print(np.sum([np.prod(v.get_shape().as_list()) for v in lstm.trainable_variables]))
lstm.save_weights('gdrive/MyDrive/trace/lstm-1')
err = 0.0
cnt = 0

for b in range(indf_test.shape[0]):
    inp = indf_test[b]
    tar = outdf_test[b]
    pred = lstm(inp)
    cnt += 1
    err += loss_function(tar, pred, 'MAE')

print(err/cnt)
# Out:
# 652920
# tf.Tensor(0.04418789, shape=(), dtype=float32)
